# %% [markdown]
# - Business Problem :
#   Prepare a prediction model for profit of 50_startups data
#   Do transformations for getting better predictions of profit and
#   make a table containing R^2 value for each prepared model.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# - Data collection and Description

# %%
df = pd.read_csv('50_Startups.csv')

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df["State"].unique()
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %% [markdown]
# - Encording

# %%
df = pd.get_dummies(df,columns = ['State'])

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit  State_California  \
# 0  165349.20       136897.80        471784.10  192261.83                 0
# 1  162597.70       151377.59        443898.53  191792.06                 1
# 2  153441.51       101145.55        407934.54  191050.39                 0
# 3  144372.41       118671.85        383199.62  182901.99                 0
# 4  142107.34        91391.77        366168.42  166187.94                 0
#
#    State_Florida  State_New York
# 0              0               1
# 1              0               0
# 2              1               0
# 3              0               1
# 4              1               0

# %%
df = df.rename({'R&D Spend':'RandD','Marketing Spend':'Marketing','State_California':'StateCal','State_Florida':'StateFlo','State_New York':'StateNY'},axis=1)

# %%
df.head()
# Out:
#        RandD  Administration  Marketing     Profit  StateCal  StateFlo  \
# 0  165349.20       136897.80  471784.10  192261.83         0         0
# 1  162597.70       151377.59  443898.53  191792.06         1         0
# 2  153441.51       101145.55  407934.54  191050.39         0         1
# 3  144372.41       118671.85  383199.62  182901.99         0         0
# 4  142107.34        91391.77  366168.42  166187.94         0         1
#
#    StateNY
# 0        1
# 1        0
# 2        0
# 3        1
# 4        0

# %% [markdown]
# # Correlation Matrix

# %%
sns.heatmap(df.corr(),annot =True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Finding Variance Inflation Factor(VIF)

# %%
x = df[['RandD','Administration','Marketing','StateCal','StateFlo','StateNY']]
y = df[['Profit']]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()

# %%
vif["VIF Factor"] = [variance_inflation_factor(x.values,i)for i in range(x.shape[1]) ]

# %%
vif["feature"] = x.columns

# %%
vif.round(1)
# Out:
#    VIF Factor         feature
# 0         2.5           RandD
# 1         1.2  Administration
# 2         2.4       Marketing
# 3         9.0        StateCal
# 4         9.4        StateFlo
# 5         9.2         StateNY

# %% [markdown]
# # ModelBuilding

# %%
import statsmodels.formula.api as smf

# %%
model = smf.ols('Profit~RandD+Administration+Marketing+StateCal+StateFlo+StateNY',data = df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     169.9
# Date:                Thu, 02 Mar 2023   Prob (F-statistic):           1.34e-27
# Time:                        13:59:24   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1063.
# Df Residuals:                      44   BIC:                             1074.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
model1 = smf.ols('Profit~RandD+Administration+Marketing',data = df).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Thu, 02 Mar 2023   Prob (F-statistic):           4.53e-30
# Time:                        14:00:30   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
#Subset selection

# %%
model1 = smf.ols("Profit~RandD+Administration+Marketing",data=df).fit()

print(model.rsquared,model.aic)
# Out:
# 0.9507459940683246 1058.7714985998055

# %%
model = smf.ols("Profit~RandD+Administration+Marketing+StateCal+StateFlo+StateNY",data=df).fit()

print(model.rsquared,model.aic)
# Out:
# 0.9507524843355148 1062.764909597834

# %%
# Model Validation Techniques

# %%
import statsmodels.api as sm

# %%
model1.resid
# Out:
# 0      -259.422890
# 1      2635.291768
# 2      8903.110904
# 3      9205.289974
# 4     -5951.574183
# 5     -6589.660571
# 6     -1991.586669
# 7     -4268.763048
# 8       470.070301
# 9     -5124.724110
# 10    10612.933633
# 11     8685.687039
# 12    12447.465818
# 13     6819.358337
# 14   -16945.996335
# 15   -16318.119985
# 16    10077.524599
# 17    -4822.077208
# 18    -4747.326806
# 19     7141.643633
# 20     1834.360769
# 21    -6006.431640
# 22    -4354.731717
# 23    -1262.625221
# 24    -4810.926113
# 25     5166.614935
# 26    -4867.035350
# 27    -9399.761457
# 28     1622.353995
# 29     -790.343452
# 30      485.217064
# 31     -204.296276
# 32    -1573.488985
# 33    -1136.087805
# 34     7673.526259
# 35     5967.910432
# 36    15422.015415
# 37      329.602292
# 38    11531.629352
# 39    -2723.251977
# 40     3423.956009
# 41     2996.273761
# 42      878.078179
# 43     9591.940037
# 44      588.975084
# 45    17275.430313
# 46    -6675.456853
# ...

# %%
sm.qqplot(model.resid,line="q");

# %% [markdown]
# # Model Techiniques
# - Finding Cook's Distance

# %%
model1 = smf.ols("Profit~RandD+Administration+Marketing",data=df).fit()

# %%
inf = model1.get_influence()
c,p = inf.cooks_distance
c
# Out:
# array([3.21825244e-05, 3.27591036e-03, 3.23842699e-02, 2.17206555e-02,
#        1.44833032e-02, 1.17158463e-02, 2.91766303e-03, 3.56513444e-03,
#        4.04303948e-05, 4.86758017e-03, 1.51064757e-02, 1.63564959e-02,
#        1.15516625e-02, 4.01422811e-03, 6.12934253e-02, 3.40013448e-02,
#        8.33556413e-03, 3.30534399e-03, 2.16819303e-03, 4.07440577e-02,
#        4.25137222e-04, 1.09844352e-02, 2.91768000e-03, 2.76030254e-04,
#        5.04643588e-03, 3.00074623e-03, 3.41957068e-03, 2.98396413e-02,
#        1.31590664e-03, 1.25992620e-04, 4.18505125e-05, 9.27434786e-06,
#        7.08656521e-04, 1.28122674e-04, 2.09815032e-02, 6.69508674e-03,
#        5.55314705e-02, 6.55050578e-05, 5.61547311e-02, 1.54279607e-03,
#        1.84850929e-03, 1.97578066e-03, 1.36089280e-04, 2.05553171e-02,
#        1.23156041e-04, 9.03234206e-02, 5.45303387e-02, 5.33885616e-03,
#        1.90527441e-01, 2.88082293e-01])

# %%
# cook's Distance plot
plt.stem(range(len(df)),c)
# Out:
# <StemContainer object of 3 artists>

# %%
np.argmax(c),np.max(c)
# Out:
# (49, 0.28808229275432634)

# %% [markdown]
# # Improving the model

# %%
df.drop(index=[49],inplace=True)

# %%
df
# Out:
#         RandD  Administration  Marketing     Profit  StateCal  StateFlo  \
# 0   165349.20       136897.80  471784.10  192261.83         0         0
# 1   162597.70       151377.59  443898.53  191792.06         1         0
# 2   153441.51       101145.55  407934.54  191050.39         0         1
# 3   144372.41       118671.85  383199.62  182901.99         0         0
# 4   142107.34        91391.77  366168.42  166187.94         0         1
# 5   131876.90        99814.71  362861.36  156991.12         0         0
# 6   134615.46       147198.87  127716.82  156122.51         1         0
# 7   130298.13       145530.06  323876.68  155752.60         0         1
# 8   120542.52       148718.95  311613.29  152211.77         0         0
# 9   123334.88       108679.17  304981.62  149759.96         1         0
# 10  101913.08       110594.11  229160.95  146121.95         0         1
# 11  100671.96        91790.61  249744.55  144259.40         1         0
# ...

# %% [markdown]
# # Final Model

# %%
final_model = smf.ols("Profit~RandD+Administration+Marketing",data=df).fit()
final_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     372.8
# Date:                Thu, 02 Mar 2023   Prob (F-statistic):           8.85e-32
# Time:                        14:18:22   Log-Likelihood:                -506.28
# No. Observations:                  49   AIC:                             1021.
# Df Residuals:                      45   BIC:                             1028.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
# Predicting For new records

# %%
df.head()
# Out:
#        RandD  Administration  Marketing     Profit  StateCal  StateFlo  \
# 0  165349.20       136897.80  471784.10  192261.83         0         0
# 1  162597.70       151377.59  443898.53  191792.06         1         0
# 2  153441.51       101145.55  407934.54  191050.39         0         1
# 3  144372.41       118671.85  383199.62  182901.99         0         0
# 4  142107.34        91391.77  366168.42  166187.94         0         1
#
#    StateNY
# 0        1
# 1        0
# 2        0
# 3        1
# 4        0

# %%
newdf = pd.DataFrame({
    'RandD':[142107],
    'Administration':[151377],
    'Marketing':[336168]
})

# %%
newdf
# Out:
#     RandD  Administration  Marketing
# 0  142107          151377     336168

# %%
final_model.predict(newdf)
# Out:
# 0    168774.447124
# dtype: float64
