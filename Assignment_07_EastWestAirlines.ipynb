# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
air = pd.read_excel("EastWestAirlines.xlsx",sheet_name="data")

# %% [markdown]
# # EDA

# %%
air
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
air.rename(columns ={'ID#':'ID','Award?':'Award'},inplace=True)
air
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
air.head()
# Out:
#    ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0   1    28143           0          1          1          1          174
# 1   2    19244           0          1          1          1          215
# 2   3    41354           0          1          1          1         4123
# 3   4    14776           0          1          1          1          500
# 4   5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1

# %%
air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award              3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
air.isna().sum()
# Out:
# ID                   0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award                0
# dtype: int64

# %%
air.describe()
# Out:
#                 ID       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
x = sc.fit_transform(air)
x
# Out:
# array([[-1.73512503e+00, -4.51140783e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-1.73426342e+00, -5.39456874e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-1.73340181e+00, -3.20031232e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [ 1.72682006e+00, -4.29480975e-05, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [ 1.72768167e+00, -1.85606976e-01, -1.86298687e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [ 1.72854328e+00, -7.00507951e-01, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %% [markdown]
# # Hierarchical Clustering

# %%
from scipy.cluster import hierarchy

# %%
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 300

# %%
lk = hierarchy.linkage(x,method = 'average')
dendrogram = hierarchy.dendrogram(lk)

# %% [markdown]
# # Model Building

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
hcair = AgglomerativeClustering(n_clusters=5)
yhc = hcair.fit_predict(x)
clusters = pd.DataFrame(yhc,columns=['Clusters'])

# %%
# Evaluation of Model

# %%
silhouette_score(x,yhc)
# Out:
# 0.21818887194803396

# %%
yhc
# Out:
# array([1, 1, 1, ..., 0, 1, 1], dtype=int64)

# %%
airline1 =pd.concat([air,clusters],axis =1)

# %%
airline1
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %% [markdown]
# # K-Means

# %%
from sklearn.cluster import KMeans

# %%
km = KMeans()
ykm = km.fit_predict(x)
ykm
# Out:
# array([4, 4, 4, ..., 2, 0, 0])

# %%
km.cluster_centers_
# Out:
# array([[ 9.72779601e-01, -3.91927844e-01, -1.33424409e-01,
#         -7.19054893e-01, -9.82418871e-02, -6.27665798e-02,
#         -5.79493454e-01, -6.35271467e-01, -1.78346805e-01,
#         -2.04443829e-01, -9.68526948e-01, -4.56802069e-01],
#        [-2.69077501e-01,  1.17503923e+00,  5.01424490e-01,
#          1.23365368e-01, -9.82418871e-02, -6.27665798e-02,
#          7.40471967e-01,  1.92550188e+00,  4.23998799e+00,
#          4.56279544e+00,  2.85820378e-01,  9.61945001e-01],
#        [ 5.38525958e-01,  3.99809706e-03, -1.30005333e-01,
#          8.27604818e-01, -9.82418871e-02, -4.89031929e-02,
#          3.94843538e-01,  6.42895211e-01, -1.25559681e-01,
#         -1.31684389e-01, -5.18608545e-01,  3.53967011e-01],
#        [ 2.19324852e-01, -4.68896637e-02, -1.56235600e-01,
#         -6.68227273e-01,  9.03825361e+00, -6.27665798e-02,
#         -1.01665326e-01,  6.17851143e-01,  8.75493989e-02,
#          2.20346809e-01, -7.24639805e-02,  5.17838824e-02],
# ...

# %% [markdown]
# # Elbow graph

# %%
wcss = []
for i in range(1,21):
    km = KMeans(n_clusters=i)
    km.fit_predict(x)
    wcss.append(km.inertia_)

# %%
wcss
# Out:
# [47987.99999999998,
#  39018.76263612887,
#  34536.015504088726,
#  30616.59629528609,
#  26894.75305989323,
#  23490.746446177618,
#  20922.732817896485,
#  19330.32873236954,
#  18014.58941292046,
#  16845.147719224362,
#  15776.965194212968,
#  15022.166797050413,
#  14324.57768590239,
#  13635.864499871705,
#  13140.629190189884,
#  12718.212669989502,
#  12206.77750950573,
#  11839.035776864592,
#  11441.95348109301,
#  11109.279796011399]

# %%
plt.plot(range(1,21), wcss)
plt.xlabel('K-values')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %% [markdown]
# # Final Model

# %%
km = KMeans(n_clusters=5)
ykm = km.fit_predict(x)
ykm
# Out:
# array([4, 4, 4, ..., 1, 1, 1])

# %%
clusters = pd.DataFrame(ykm,columns=['Clusters'])

# %%
airline2 =pd.concat([air,clusters],axis =1)

# %%
airline2
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %% [markdown]
# # Evaluation of KMeans

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(x,ykm)
# Out:
# 0.23903010621779597

# %%
from yellowbrick.cluster import SilhouetteVisualizer

# %%
model = KMeans(n_clusters=5)
vis = SilhouetteVisualizer(model)

vis.fit(x)
vis.show()
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 3999 Samples in 5 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %% [markdown]
# # DBscan

# %%
air.head()
# Out:
#    ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0   1    28143           0          1          1          1          174
# 1   2    19244           0          1          1          1          215
# 2   3    41354           0          1          1          1         4123
# 3   4    14776           0          1          1          1          500
# 4   5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1

# %%
from sklearn.cluster import DBSCAN

# %%
db = DBSCAN()
ydb = db.fit_predict(x)
ydb
# Out:
# array([ 0,  0,  0, ..., -1,  0,  0], dtype=int64)

# %%
silhouette_score(x,ydb)
# Out:
# -0.2823258834687895

# %% [markdown]
# # hyperparameter tuning
# - finding out the best eps values(k-dist)

# %%
from sklearn.neighbors import NearestNeighbors

# %%
neigh = NearestNeighbors(n_neighbors=7).fit(x)
dist,ind = neigh.kneighbors(x)

# %%
pd.DataFrame(dist)
# Out:
#         0         1         2         3         4         5         6
# 0     0.0  0.135379  0.137435  0.153970  0.158870  0.166883  0.195590
# 1     0.0  0.114076  0.137435  0.210747  0.211117  0.211364  0.216334
# 2     0.0  0.219562  0.272519  0.329144  0.332584  0.336416  0.344587
# 3     0.0  0.107546  0.112031  0.114076  0.133451  0.135379  0.145879
# 4     0.0  0.560199  0.774714  0.786941  1.163804  1.190904  1.209665
# ...   ...       ...       ...       ...       ...       ...       ...
# 3994  0.0  0.374224  0.418542  0.454143  0.478637  0.485146  0.489619
# 3995  0.0  0.375466  0.444557  0.575671  0.590940  0.622345  0.622966
# 3996  0.0  0.195238  0.327193  0.554107  0.678597  0.766695  0.920865
# 3997  0.0  0.289179  0.330073  0.412335  0.453135  0.468078  0.477746
# 3998  0.0  0.027522  0.065043  0.075607  0.115131  0.120550  0.134656
#
# [3999 rows x 7 columns]

# %%
distance = np.sort(dist[:,1],axis=0)

# %%
distance
# Out:
# array([2.42270462e-03, 2.42270462e-03, 4.69027727e-03, ...,
#        6.66765339e+00, 6.68121018e+00, 7.58357087e+00])

# %%
sns.set_style('darkgrid')
plt.plot(distance)

# %%
db = DBSCAN(eps=3,min_samples=5)
ydb = db.fit_predict(x)
ydb
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# # Evaluation of DBscan

# %%
silhouette_score(x,ydb)
# Out:
# 0.5136199917197446

# %%
cl = pd.DataFrame(ydb,columns=['Cluster'])

# %%
airDB = pd.concat([air,cl],axis = 1)
airDB
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airDB['Cluster'].value_counts()
# Out:
#  0    3888
# -1      73
#  2      25
#  1      13
# Name: Cluster, dtype: int64

# %% [markdown]
# # Conclusion
# - silhouette_score for DBscan is 0.51
# - silhouette_score for KMean is 0.23
# - In Airlines we make 5 clusters according to DBscan ,KMean and Hierarchical clusters
